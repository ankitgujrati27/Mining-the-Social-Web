# %% [markdown]
# # Collect set of trend for both entire world and USA

# %%
# Initializing the twitter API

# %%
CONSUMER_KEY = ''
CONSUMER_SECRET = ''
OAUTH_TOKEN = ''
OAUTH_TOKEN_SECRET = ''

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET, CONSUMER_KEY, CONSUMER_SECRET)
twitter_api = twitter.Twitter(auth=auth)

# %%
# The Where on Earth ID for entire world is 1 and for USA is 23424977.
# You may get it from https://dev.twitter.com/docs/api/1.1/get/trends/place

# %%
import twitter

# %%
World_woe_id = 1
USA_woe_id = 23424977

# %%
world_trends = twitter_api.trends.place(_id=World_woe_id)
us_trends = twitter_api.trends.place(_id=USA_woe_id)

# %%
print world_trends
print
print us_trends
# Out:
# [{u'created_at': u'2017-02-24T18:32:53Z', u'trends': [{u'url': u'http://twitter.com/search?q=%23%D8%A7%D9%84%D8%B9%D9%8A%D8%AF_%D8%A7%D9%84%D9%88%D8%B7%D9%86%D9%8A_%D8%A7%D9%84%D9%83%D9%88%D9%8A%D8%AA%D9%8A', u'query': u'%23%D8%A7%D9%84%D8%B9%D9%8A%D8%AF_%D8%A7%D9%84%D9%88%D8%B7%D9%86%D9%8A_%D8%A7%D9%84%D9%83%D9%88%D9%8A%D8%AA%D9%8A', u'tweet_volume': None, u'name': u'#\u0627\u0644\u0639\u064a\u062f_\u0627\u0644\u0648\u0637\u0646\u064a_\u0627\u0644\u0643\u0648\u064a\u062a\u064a', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23DiaDeLaBandera', u'query': u'%23DiaDeLaBandera', u'tweet_volume': 30971, u'name': u'#DiaDeLaBandera', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23Payitaht', u'query': u'%23Payitaht', u'tweet_volume': 20148, u'name': u'#Payitaht', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23CPAC2017', u'query': u'%23CPAC2017', u'tweet_volume': 255404, u'name': u'#CPAC2017', u'promoted_content': None}, {u'u
# ...

# %%
# Making output as more human readable

import json

# %%
print json.dumps(world_trends, indent=1)
# Out:
# [
#  {
#   "created_at": "2017-02-24T18:32:53Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%84%D8%B9%D9%8A%D8%AF_%D8%A7%D9%84%D9%88%D8%B7%D9%86%D9%8A_%D8%A7%D9%84%D9%83%D9%88%D9%8A%D8%AA%D9%8A",
#     "query": "%23%D8%A7%D9%84%D8%B9%D9%8A%D8%AF_%D8%A7%D9%84%D9%88%D8%B7%D9%86%D9%8A_%D8%A7%D9%84%D9%83%D9%88%D9%8A%D8%AA%D9%8A",
#     "tweet_volume": null,
#     "name": "#\u0627\u0644\u0639\u064a\u062f_\u0627\u0644\u0648\u0637\u0646\u064a_\u0627\u0644\u0643\u0648\u064a\u062a\u064a",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23DiaDeLaBandera",
#     "query": "%23DiaDeLaBandera",
#     "tweet_volume": 30971,
#     "name": "#DiaDeLaBandera",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Payitaht",
#     "query": "%23Payitaht",
#     "tweet_volume": 20148,
#     "name": "#Payitaht",
#     "promoted_content": null
#    },
#    {
# ...

# %%
print json.dumps(us_trends, indent=1)
# Out:
# [
#  {
#   "created_at": "2017-02-24T18:38:00Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%23CPAC2017",
#     "query": "%23CPAC2017",
#     "tweet_volume": 257283,
#     "name": "#CPAC2017",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23FridayFeeling",
#     "query": "%23FridayFeeling",
#     "tweet_volume": 75646,
#     "name": "#FridayFeeling",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23FlashbackFriday",
#     "query": "%23FlashbackFriday",
#     "tweet_volume": 17885,
#     "name": "#FlashbackFriday",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23BotherATVShow",
#     "query": "%23BotherATVShow",
#     "tweet_volume": null,
#     "name": "#BotherATVShow",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23IStandUpToBulliesBy",
#     "query": "%23IStandUpToBulliesBy",
# ...
